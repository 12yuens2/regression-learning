# %% [markdown]
# # Load dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
EnergySet = pd.read_csv("data/energydata_complete.csv")
energydf = pd.DataFrame(data=EnergySet)

# %% [markdown]
# # Split training and test data sets

# %%
from sklearn.model_selection import train_test_split

# Split into training and test data
energy_train, energy_test = train_test_split(energydf, test_size=0.2, random_state=12)

# %% [markdown]
# # Preprocessing
# Cleaning the data and converting any data types

# %% [markdown]
# For showing off our preprocessing steps, a copy of the training data is used. The proper preprocessing is done in the pipeline later.

# %%
preprocessing_set = energy_train.copy()

# %%
# See if there are incorrect values from mix/max
# eg, negative humidity
pd.set_option("display.max_columns", 30)
preprocessing_set.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  15788.000000  15788.000000  15788.000000  15788.000000  15788.000000
# mean      97.994680      3.797821     21.685162     40.241478     20.333469
# std      103.412819      7.906476      1.600368      3.985224      2.189181
# min       10.000000      0.000000     16.790000     27.360000     16.100000
# 25%       50.000000      0.000000     20.760000     37.295833     18.823333
# 50%       60.000000      0.000000     21.600000     39.626667     19.963333
# 75%      100.000000      0.000000     22.600000     43.060000     21.500000
# max     1080.000000     70.000000     26.260000     59.633333     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  15788.000000  15788.000000  15788.000000  15788.000000  15788.000000
# mean      40.414087     22.265809     39.219934     20.856898     39.002723
# std        4.070580      2.001268      3.254534      2.039275      4.343747
# min       20.463333     17.200000     28.766667     15.100000     28.135714
# 25%       37.863333     20.790000     36.900000     19.533333     35.500000
# 50%       40.500000     22.100000     38.500000     20.666667     38.400000
# 75%       43.260000     23.290000     41.700000     22.100000     42.126667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#                  T5          RH_5            T6          RH_6            T7  \
# count  15788.000000  15788.000000  15788.000000  15788.000000  15788.000000
# mean      19.596673     50.962286      7.900954     54.504225     20.273681
# std        1.840384      9.028186      6.067980     31.051305      2.103267
# min       15.335000     29.815000     -6.065000      1.000000     15.390000
# 25%       18.290000     45.400000      3.626667     30.093333     18.719500
# 50%       19.390000     49.090000      7.330000     55.200000     20.100000
# 75%       20.628571     53.679328     11.226667     83.060833     21.600000
# max       25.795000     96.321667     28.290000     99.900000     25.963333
#
#                RH_7            T8          RH_8            T9          RH_9  \
# count  15788.000000  15788.000000  15788.000000  15788.000000  15788.000000
# mean      35.362159     22.037050     42.908320     19.491903     41.533531
# std        5.115052      1.951244      5.219348      2.011131      4.144814
# min       23.200000     16.306667     29.600000     14.890000     29.166667
# 25%       31.468571     20.790000     39.030000     18.033333     38.500000
# 50%       34.794000     22.133333     42.292857     19.390000     40.863333
# 75%       39.000000     23.390000     46.500000     20.600000     44.290000
# max       51.400000     27.230000     58.780000     24.500000     53.326667
#
#               T_out   Press_mm_hg        RH_out     Windspeed    Visibility  \
# count  15788.000000  15788.000000  15788.000000  15788.000000  15788.000000
# mean       7.402040    755.562843     79.758302      4.029516     38.381684
# std        5.296268      7.403755     14.859219      2.437627     11.801692
# min       -5.000000    729.300000     24.000000      0.000000      1.000000
# 25%        3.683333    750.966667     70.333333      2.000000     29.000000
# 50%        6.933333    756.100000     83.666667      3.666667     40.000000
# 75%       10.400000    760.966667     91.500000      5.500000     40.000000
# max       26.100000    772.300000    100.000000     13.000000     66.000000
#
#           Tdewpoint           rv1           rv2
# count  15788.000000  15788.000000  15788.000000
# mean       3.755411     24.972127     24.972127
# std        4.187296     14.466799     14.466799
# min       -6.600000      0.005322      0.005322
# 25%        0.900000     12.511579     12.511579
# 50%        3.425000     24.828135     24.828135
# 75%        6.550000     37.557288     37.557288
# max       15.400000     49.993173     49.993173

# %% [markdown]
# ## Clean data
# Clean data for invalid values like negative humidity or unrealistic temperatures

# %%
def clean_data(min_value, max_value, columns, data):
    clean_data = data.copy()
    for col in columns:
        # Only keep rows where column date is within the min and max values
        clean_data = clean_data[ (clean_data[col] <= max_value)
                               & (clean_data[col] >= min_value)]
    return clean_data

# %% [markdown]
# Example of using the `clean_data` method, where we want the column `T1` to have values between 20 and 50

# %%
clean_data(20,50,["T1"],preprocessing_set).head(3)
# Out:
#                       date  Appliances  lights         T1       RH_1    T2  \
# 11928  2016-04-03 13:00:00          80       0  22.066667  43.163333  23.7
# 11089  2016-03-28 17:10:00         110       0  23.700000  40.566667  22.5
# 8623   2016-03-11 14:10:00          60      10  20.700000  34.126667  19.5
#
#             RH_2     T3       RH_3    T4   RH_4     T5       RH_5         T6  \
# 11928  38.090000  22.20  40.590000  21.5  42.09  19.39  47.790000  19.323333
# 11089  38.966667  23.89  39.466667  21.6  39.79  20.29  46.645000  11.183333
# 8623   34.433333  19.89  34.700000  20.7  33.29  17.89  57.566667   9.330000
#
#             RH_6         T7       RH_7         T8       RH_8         T9  \
# 11928  15.700000  21.260000  38.790000  22.700000  42.863333  20.100000
# 11089  24.816667  22.166667  31.633333  23.323333  35.500000  20.566667
# 8623   29.126667  21.066667  29.500000  22.033333  35.000000  18.500000
#
#             RH_9      T_out  Press_mm_hg     RH_out  Windspeed  Visibility  \
# 11928  42.900000  18.000000   752.000000  55.000000   4.000000   40.000000
# 11089  41.433333   8.666667   743.316667  76.000000   8.666667   38.166667
# 8623   39.500000   9.416667   764.800000  53.833333   4.000000   27.500000
#
#        Tdewpoint        rv1        rv2
# 11928       8.90  29.765861  29.765861
# 11089       4.55  37.361588  37.361588
# 8623        0.45  10.094660  10.094660

# %% [markdown]
# ## Data Visualisation
# Plot visualisations of data to see if we can gain any insight

# %% [markdown]
# ### Histograms

# %%
hists = preprocessing_set.hist(bins=100,figsize=(20,15))

# %% [markdown]
# ### Temperature/humidity correlation
# Correlation between each temperature/humidity reading as they on the same sensor

# %%
Ts = ["T1", "T2", "T3", "T4", "T5", "T6", "T7", "T8", "T9", "T_out"]
RHs = ["RH_1", "RH_2", "RH_3", "RH_4", "RH_5", "RH_6", "RH_7", "RH_8", "RH_9", "RH_out"]

# %%
fig = plt.figure(figsize=(15,12))
fig.subplots_adjust(wspace=0.5)
for i in range(len(Ts)):
    plt.subplot(3,4,(i+1))
    plt.scatter(preprocessing_set[Ts[i]], preprocessing_set[RHs[i]], alpha=0.02)
    plt.xlabel(Ts[i])
    plt.ylabel(RHs[i])

# %% [markdown]
# ## Convert date timestamp to numeric values

# %%
from datetime import datetime

def parse_timestamp(timestamp):
    return datetime.strptime(timestamp, "%Y-%m-%d %H:%M:%S")

# %% [markdown]
# A testing dataframe is populated here to show examples of each conversion

# %%
time_test = preprocessing_set.copy()
time_test = time_test.loc[:, "date":"Appliances"]

# %% [markdown]
# ### Numeric
# Turn datetime into basic numeric forms, for example monday=0, tuesday=1...

# %%
def get_numeric_time(timestamp):
    dt = parse_timestamp(timestamp)
    hour = dt.hour
    day = dt.weekday()
    
    return hour,day

# %% [markdown]
# Example numeric time conversion

# %%
time_test[["hour_num", "day_num"]] = preprocessing_set["date"].map(get_numeric_time).apply(pd.Series)

# %%
time_test[["date","hour_num", "day_num"]].head(5)
# Out:
#                       date  hour_num  day_num
# 11928  2016-04-03 13:00:00        13        6
# 11089  2016-03-28 17:10:00        17        0
# 8623   2016-03-11 14:10:00        14        4
# 15433  2016-04-27 21:10:00        21        2
# 11827  2016-04-02 20:10:00        20        5

# %% [markdown]
# ### Cyclic
# Due to the nature of time being cyclical, we want to keep this characteristic for our learning model. A way to do this is using sine and cosine transformations.
# https://ianlondon.github.io/blog/encoding-cyclical-features-24hour-time/

# %%
def get_cyclic_time(timestamp):
    dt = parse_timestamp(timestamp)
    
    hour_sin = np.sin(2*np.pi*dt.hour/24)
    hour_cos = np.cos(2*np.pi*dt.hour/24)
    day_sin = np.sin(2*np.pi*dt.weekday()/7)
    day_cos = np.cos(2*np.pi*dt.weekday()/7)
    
    return hour_sin, hour_cos, day_sin, day_cos

# %% [markdown]
# Example cyclic time conversion

# %%
time_test[["hour_sin", "hour_cos", "day_sin", "day_cos"]] = preprocessing_set["date"].map(get_cyclic_time).apply(pd.Series)

# %%
time_test[["date", "hour_sin", "hour_cos", "day_sin", "day_cos"]].head(5)
# Out:
#                       date  hour_sin  hour_cos   day_sin   day_cos
# 11928  2016-04-03 13:00:00 -0.258819 -0.965926 -0.781831  0.623490
# 11089  2016-03-28 17:10:00 -0.965926 -0.258819  0.000000  1.000000
# 8623   2016-03-11 14:10:00 -0.500000 -0.866025 -0.433884 -0.900969
# 15433  2016-04-27 21:10:00 -0.707107  0.707107  0.974928 -0.222521
# 11827  2016-04-02 20:10:00 -0.866025  0.500000 -0.974928 -0.222521

# %% [markdown]
# ### Seconds from midnight
# A feature used by the paper is to extract the timestamp as the number of seconds from midnight (NSM) instead of using the actual hours of the day

# %%
def get_nsm(timestamp):
    dt = parse_timestamp(timestamp)
    midnight = dt.replace(hour=0, minute=0, second=0, microsecond=0)
    
    seconds = (dt - midnight).seconds
    
    return seconds
    
def get_cyclic_nsm(timestamp):
    seconds = get_nsm(timestamp)
    seconds_sin = np.sin(2*np.pi*seconds/(24*60*60))
    seconds_cos = np.cos(2*np.pi*seconds/(24*60*60))
    
    return seconds_sin, seconds_cos

# %% [markdown]
# Example NSM conversion

# %%
time_test[["NSM"]] = preprocessing_set["date"].map(get_nsm).apply(pd.Series)
time_test[["NSM_sin", "NSM_cos"]] = preprocessing_set["date"].map(get_cyclic_nsm).apply(pd.Series)

# %%
time_test[["NSM", "NSM_sin", "NSM_cos"]].head(5)
# Out:
#          NSM   NSM_sin   NSM_cos
# 11928  46800 -0.258819 -0.965926
# 11089  61800 -0.976296 -0.216440
# 8623   51000 -0.537300 -0.843391
# 15433  76200 -0.675590  0.737277
# 11827  72600 -0.843391  0.537300

# %% [markdown]
# ### Categorical day of the week
# As NSM does not convey any information about the day of the week, we can also convert the date into categorical values for each day of the week

# %%
def get_categorical_day(timestamp):
    dt = parse_timestamp(timestamp)
    day_num = dt.weekday()

    # Categories in order: Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, Sunday
    categories = [0,0,0,0,0,0,0]
    categories[day_num] = 1
    
    return tuple(categories)

# %%
days_of_week = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
time_test[days_of_week] = preprocessing_set["date"].map(get_categorical_day).apply(pd.Series)

# %%
time_test[["date"] + days_of_week].head(5)
# Out:
#                       date  Monday  Tuesday  Wednesday  Thursday  Friday  \
# 11928  2016-04-03 13:00:00       0        0          0         0       0
# 11089  2016-03-28 17:10:00       1        0          0         0       0
# 8623   2016-03-11 14:10:00       0        0          0         0       1
# 15433  2016-04-27 21:10:00       0        0          1         0       0
# 11827  2016-04-02 20:10:00       0        0          0         0       0
#
#        Saturday  Sunday
# 11928         0       1
# 11089         0       0
# 8623          0       0
# 15433         0       0
# 11827         1       0

# %% [markdown]
# ### Comparison of different timestamp metrics.

# %%
time_correlation = time_test.corr()
time_correlation["Appliances"].map(abs).sort_values(ascending=False)
# Out:
# Appliances    1.000000
# NSM_sin       0.259581
# hour_sin      0.235093
# hour_cos      0.233518
# NSM           0.215358
# hour_num      0.215016
# NSM_cos       0.205434
# day_sin       0.054228
# Monday        0.052503
# Tuesday       0.043997
# Saturday      0.032062
# Wednesday     0.030169
# Friday        0.026120
# Thursday      0.024768
# Sunday        0.010392
# day_cos       0.008363
# day_num       0.003635
# Name: Appliances, dtype: float64

# %% [markdown]
# ## Visualise feature correlation

# %%
correlation = preprocessing_set.corr().abs()

# %%
# visualise with all new time inputs
preprocessing_set[["NSM_sin", "NSM_cos"]] = preprocessing_set["date"].map(get_cyclic_nsm).apply(pd.Series)
preprocessing_set[["hour_sin", "hour_cos", "day_sin", "day_cos"]] = preprocessing_set["date"].map(get_cyclic_time).apply(pd.Series)
preprocessing_set[["hour_num", "day_num"]] = preprocessing_set["date"].map(get_numeric_time).apply(pd.Series)
preprocessing_set[days_of_week] = preprocessing_set["date"].map(get_categorical_day).apply(pd.Series)

# %%
# Visualisation code adapted from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
import seaborn as sns

# Mask upper half as it is just the mirror of the lower half
mask = np.zeros_like(correlation, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Colormap
cmap = sns.diverging_palette(220,10,as_cmap=True)

plt.figure(figsize=(12,12))
sns.heatmap(correlation, mask=mask, cmap=cmap, center=0, square=True, linewidths=0.5)

# %%
# Correlation of each input feature with the output
correlation["Appliances"].map(abs).sort_values(ascending=False)
# Out:
# Appliances     1.000000
# lights         0.193783
# RH_out         0.153771
# T2             0.124479
# T6             0.121832
# T_out          0.103091
# RH_8           0.090435
# RH_1           0.088373
# T3             0.086108
# Windspeed      0.085736
# RH_6           0.084453
# RH_2           0.062802
# T1             0.057280
# RH_7           0.050674
# RH_9           0.049955
# T4             0.042697
# T8             0.039928
# RH_3           0.036624
# Press_mm_hg    0.035069
# T7             0.027280
# T5             0.023441
# RH_4           0.020576
# Tdewpoint      0.018647
# T9             0.011721
# rv1            0.010021
# rv2            0.010021
# RH_5           0.008056
# Visibility     0.007061
# Name: Appliances, dtype: float64

# %% [markdown]
# ## Pipelines
# All the steps done above can be converted into pipelines. This allows us to modularly choose the exact stages to go through.

# %%
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

# %% [markdown]
# #### Cleaning pipeline stage

# %%
class DataCleaner(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self # No fitting for cleaning step
        
    def transform(self, X):
        # Temperature columns
        Tcols= ["T1", "T2", "T3", "T4", "T5", "T6", "T7", "T8", "T9", "T_out", "Tdewpoint"]
        
        # Humidity columns
        RHcols = ["RH_1", "RH_2", "RH_3", "RH_4", "RH_5", "RH_6", "RH_7", "RH_8", "RH_9", "RH_out"]
        
        # Non negative columns
        Ncols = ["lights", "Windspeed", "Visibility", "Press_mm_hg"]
        
        X = self.clean_data(-50,50,Tcols,X) # Clean temperatures
        X = self.clean_data(0,100,RHcols,X) # Clean humidity
        X = self.clean_data(0,1100,Ncols,X) # Clean non negative values, 1080 was the maximum value of any data cell from peeking at data with DataFrame.describe()
        
        return X
    

    def clean_data(self, min_value, max_value, columns, data):
        clean_data = data.copy()
        for col in columns:
            clean_data = clean_data[ (clean_data[col] <= max_value)
                                   & (clean_data[col] >= min_value)]
        return clean_data

# %% [markdown]
# #### Datetime transformation stage

# %%
# This transformer takes the DataFrame and converts the date timestamp
# The date column is then dropped
class DatetimeTransformer(BaseEstimator, TransformerMixin):
        
    def fit(self, X, y=None):
        return self # No fitting in transformer
    
    def transform(self, X):
        cyclic_columns = ["hour_sin", "hour_cos", "day_sin", "day_cos"]    
        X[cyclic_columns] = self.mapTransformation(X, get_cyclic_time)
        X.drop(["day_sin", "day_cos"], axis=1)
        
        categorical_columns = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"] 
        X[categorical_columns] = self.mapTransformation(X, get_categorical_day)
        
        return self.dropDate(X)
        
    def mapTransformation(self, X, mapper):
        return X["date"].map(mapper).apply(pd.Series)
    
    def dropDate(self, X):
        return X.drop("date", axis=1)

# %% [markdown]
# #### Feature selection stage
# Drop features below random variable correlation

# %%
preprocessing_set.corr()["Appliances"].map(abs).sort_values(ascending=False)
# Out:
# Appliances     1.000000
# NSM_sin        0.259581
# hour_sin       0.235093
# hour_cos       0.233518
# hour_num       0.215016
# NSM_cos        0.205434
# lights         0.193783
# RH_out         0.153771
# T2             0.124479
# T6             0.121832
# T_out          0.103091
# RH_8           0.090435
# RH_1           0.088373
# T3             0.086108
# Windspeed      0.085736
# RH_6           0.084453
# RH_2           0.062802
# T1             0.057280
# day_sin        0.054228
# Monday         0.052503
# RH_7           0.050674
# RH_9           0.049955
# Tuesday        0.043997
# T4             0.042697
# T8             0.039928
# RH_3           0.036624
# Press_mm_hg    0.035069
# Saturday       0.032062
# Wednesday      0.030169
# T7             0.027280
# Friday         0.026120
# Thursday       0.024768
# T5             0.023441
# RH_4           0.020576
# Tdewpoint      0.018647
# T9             0.011721
# Sunday         0.010392
# rv1            0.010021
# rv2            0.010021
# day_cos        0.008363
# RH_5           0.008056
# Visibility     0.007061
# day_num        0.003635
# Name: Appliances, dtype: float64

# %% [markdown]
# We want to remove RH_5 and Visibility in addition to the random variables as they have lower correlation than the random variables. We do not worry about day_cos and day_num as they are not used in our time conversion pipeline step.

# %%
class SimpleFeatureSelector(BaseEstimator, TransformerMixin):
    
    def __init__(self):
        self.df = None
    
    def fit(self, X, y=None):        
        return self
            
    
    def transform(self, X):
        unwanted_features = ["rv1", "rv2", "Visibility", "RH_5"]

        return X.drop(unwanted_features, axis=1)

# %% [markdown]
# ## Model selection and training

# %% [markdown]
# First, create trainer object to make training and predicting with the pipelines easier

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Trainer object to abstract over training and predicting
class Trainer():
    def __init__(self, preprocess, model, input, output, kfold=5):
        self.model = model
        self.preprocess = preprocess
        self.input = input
        self.output = output
        self.kfold = kfold
    
    def train(self, params=False):
        processed_input = self.preprocess.fit_transform(self.input, self.output)
        
        if not params:
            self.model.fit(processed_input, self.output)
            return self.cross_validate(processed_input, self.model)
        else:
            self.model.fit(processed_input, self.output)
            best_model = self.get_model().best_estimator_
            return self.cross_validate(processed_input, model=best_model)
    
    def get_model(self):
        return self.model.named_steps["model"]
    
    
    def predict(self, input, output):
        # output needed for preprocessing step in pipeline
        processed_input = self.preprocess.fit_transform(input, output)
        return self.get_model().predict(processed_input)
    
    def cross_validate(self, processed_input, model):
        prediction = cross_val_predict(model, processed_input, self.output, cv=self.kfold)
        rmse = np.sqrt(mean_squared_error(self.output, prediction))
        r2 = r2_score(self.output, prediction)
        
        return rmse,r2

# %% [markdown]
# Next, create function to help plot and visualise data after predictions

# %%
# Function to plot predicted values and residual
def plot_results(predicted_values, true_values, title):
    fig = plt.figure(figsize=(5,10))
    fig.subplots_adjust(wspace=0.5)
    plt.title(title)
    
    # True vs predicted graph
    plt.subplot(2,1,1)
    plt.scatter(predicted_values, true_values, alpha=0.1)
    plt.xlabel("Predicted value")
    plt.ylabel("True value")
    
    # Residual graph
    plt.subplot(2,1,2)
    plt.scatter(np.subtract(true_values, predicted_values), true_values, alpha=0.1)
    plt.xlabel("Residual")
    plt.ylabel("True value")

# %% [markdown]
# Finally, get input and output from our training data

# %%
# Drop output column for input data
input = energy_train.drop(["Appliances"], axis=1)
output = energy_train["Appliances"]

# %% [markdown]
# ### Linear Regression
# Create pipelines for preprocessing and linear regression. The preprocessing pipelines use the custom pipeline stages defined above.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression

# Pipeline using simple threshold feature selection to remove input features with less correation than the random variables
preprocessing_pipeline = Pipeline([
    ("cleaning", DataCleaner()),
    ("time_conversion", DatetimeTransformer()),
    ("feature_selection", SimpleFeatureSelector()), # Remove features with threshold less than rv1
    #("feature_scaling", StandardScaler()),
])

# Pipeline using sklearn's KBest selection.
# A low value of k was used to contrast the larger number of features of the simple feature selector
kbest_pipeline = Pipeline([
    ("cleaning", DataCleaner()),
    ("time_conversion", DatetimeTransformer()),
    ("feature_selection", SelectKBest(f_regression, k=10)),
    #("feature_scaling", StandardScaler())
])


linreg_pipeline = Pipeline([
    ("model", LinearRegression())
])

# %% [markdown]
# Create a `Trainer` for linear regression and train on the training data

# %%
from sklearn.base import clone # Use clone to prevent same references issues

lin_trainer = Trainer(clone(preprocessing_pipeline), clone(linreg_pipeline), input, output, kfold=5)
lin_rmse, lin_r2 = lin_trainer.train()
lin_model = lin_trainer.get_model()

# %%
lin_rmse
# Out:
# 92.61461472422101

# %%
lin_r2
# Out:
# 0.1978828491057386

# %%
lin_predicted = lin_trainer.predict(input, output)
plot_results(lin_predicted, output, "Linear - simple selector")

# %% [markdown]
# Create another `Trainer` for linear regression, but using `SelectKBest` for the selection step in preprocessing

# %%
# Model with kbest features selected
lin_kbest_trainer = Trainer(clone(kbest_pipeline), clone(linreg_pipeline), input, output, kfold=5)
lin_kbest_rmse, lin_kbest_r2 = lin_kbest_trainer.train()
lin_kbest_model = lin_kbest_trainer.get_model()

# %%
lin_kbest_rmse
# Out:
# 94.86031985730149

# %%
lin_kbest_r2
# Out:
# 0.15851200771779195

# %%
lin_kbest_predicted = lin_kbest_trainer.predict(input, output)
plot_results(lin_kbest_predicted, output, "Linear - KBest selector")

# %% [markdown]
# ### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# Pipeline using simple threshold feature selection to remove input features with less correation than the random variables
poly_preprocessing_pipeline = Pipeline([
    ("cleaning", DataCleaner()),
    ("time_conversion", DatetimeTransformer()),
    ("feature_selection", SimpleFeatureSelector()), # Remove features with threshold less than rv1
    #("feature_scaling", StandardScaler()),
    ("poly_features", PolynomialFeatures(degree=2))
])

# Pipeline using sklearn's KBest selection.
# A low value of k was used to contrast the larger number of features of the simple feature selector
poly_kbest_pipeline = Pipeline([
    ("cleaning", DataCleaner()),
    ("time_conversion", DatetimeTransformer()),
    ("feature_selection", SelectKBest(f_regression, k=10)),
    #("feature_scaling", StandardScaler()),
    ("poly_features", PolynomialFeatures(degree=2))
])


polyreg_pipeline = Pipeline([
    ("model", LinearRegression())
])

# %% [markdown]
# Trainer for a polynomial regression model

# %%
poly_trainer = Trainer(clone(poly_preprocessing_pipeline), clone(polyreg_pipeline), input, output, kfold=5)
poly_rmse, poly_r2 = poly_trainer.train()
poly_model = poly_trainer.get_model()

# %%
poly_rmse
# Out:
# 84.55706772171327

# %%
poly_r2
# Out:
# 0.33138120299031915

# %%
poly_predicted = poly_trainer.predict(input, output)
plot_results(poly_predicted, output, "Polynomial - Simple selector")

# %% [markdown]
# Try KBest selector again as well

# %%
poly_kbest_trainer = Trainer(clone(poly_kbest_pipeline), clone(polyreg_pipeline), input, output, kfold=5)
poly_kbest_rmse, poly_kbest_r2 = poly_kbest_trainer.train()
poly_kbest_model = poly_kbest_trainer.get_model()

# %%
poly_kbest_rmse
# Out:
# 91.76852531095788

# %%
poly_kbest_r2
# Out:
# 0.21247153660239393

# %%
poly_kbest_predicted = poly_kbest_trainer.predict(input, output)
plot_results(poly_kbest_predicted, output, "Polynomial - KBest selector")

# %% [markdown]
# # Evaluation of model

# %%
# Get test data
test_input = energy_test.drop("Appliances", axis=1)
test_output = energy_test["Appliances"]

# %%
predicted = poly_trainer.predict(test_input, test_output)
plot_results(predicted, test_output, "Testing results")

# %%
np.sqrt(mean_squared_error(test_output, predicted))
# Out:
# 80.9048622473295

# %%
r2_score(test_output, predicted)
# Out:
# 0.33059088685421656

# %%
predicted = lin_trainer.predict(test_input, test_output)
plot_results(predicted, test_output, "Testing results")

# %%
np.sqrt(mean_squared_error(test_output, predicted))
# Out:
# 80.9048622473295

# %%
r2_score(test_output, predicted)
